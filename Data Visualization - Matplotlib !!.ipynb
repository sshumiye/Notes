# %%
# used for data visualization

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

# %matplotlib inline

# %%
x = np.linspace(-6, 6, 200)

cos = np.cos(x)

plt.plot(x, cos)

# %%
x = np.linspace(-6, 6, 200)

sin = np.sin(x)

plt.plot(x, sin)

# %%
x = np.linspace(-6, 6, 200)

cos = np.cos(x)
sin = np.sin(x)

plt.plot(x, cos)
plt.plot(x, sin)

# %% [markdown]
# # Changing default properties

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

# %matplotlib inline

# %%
plt.figure(figsize=(10,5))

x = np.linspace(-6, 6, 200)

cos = np.cos(x)
sin = np.sin(x)

plt.plot(x, cos)
plt.plot(x, sin)

# %%
plt.figure(figsize=(10,6))

x = np.linspace(-6, 6, 200)

cos = np.cos(x)
sin = np.sin(x)

plt.plot(x, cos)
plt.plot(x, sin)

# %%
plt.figure(figsize=(10,6))

x = np.linspace(-6, 6, 200)

cos = np.cos(x)
sin = np.sin(x)

plt.plot(x, cos, color='red', linewidth=2.0)
plt.plot(x, sin, color='green', linewidth=3.0)

# %%
plt.figure(figsize=(10,6))

x = np.linspace(-6, 6, 200)

cos = np.cos(x)
sin = np.sin(x)

plt.plot(x, cos, color='red', linewidth=2.0)
plt.plot(x, sin, color='green', linewidth=3.0)

plt.xticks(np.linspace(-6,6,12))
plt.yticks(np.linspace(-1,1,6))
# Out:
# ([<matplotlib.axis.YTick at 0x11babbc10>,
#   <matplotlib.axis.YTick at 0x11bb43e90>,
#   <matplotlib.axis.YTick at 0x11be76fd0>,
#   <matplotlib.axis.YTick at 0x11be56550>,
#   <matplotlib.axis.YTick at 0x11be76610>,
#   <matplotlib.axis.YTick at 0x11be61f90>],
#  <a list of 6 Text yticklabel objects>)

# %%
plt.figure(figsize=(10,6))

x = np.linspace(-6, 6, 200)

cos = np.cos(x)
sin = np.sin(x)

plt.plot(x, cos, color='red', linewidth=2.0)
plt.plot(x, sin, color='green', linewidth=3.0)

plt.xticks(np.linspace(-6,6,12))
plt.yticks(np.linspace(-1,1,6))

#plt.xlim(-8,8)
#plt.ylim(-1.8,1.8)
# Out:
# ([<matplotlib.axis.YTick at 0x11ca67ed0>,
#   <matplotlib.axis.YTick at 0x11ca67990>,
#   <matplotlib.axis.YTick at 0x11caef6d0>,
#   <matplotlib.axis.YTick at 0x11caefc10>,
#   <matplotlib.axis.YTick at 0x11caf4150>,
#   <matplotlib.axis.YTick at 0x11caf4810>],
#  <a list of 6 Text yticklabel objects>)

# %% [markdown]
# # Setting ticks and limits

# %%
plt.figure(figsize=(10,5))

x = np.linspace(-6, 6, 200)

cos = np.cos(x)
sin = np.sin(x)

plt.plot(x, cos, color='red', linewidth=2.5)
plt.plot(x, sin, color='green', linewidth=3.5)

plt.xlim(-9,9)
plt.ylim(-1.4, 1.4)
# Out:
# (-1.4, 1.4)

# %%
plt.figure(figsize=(10,5))

x = np.linspace(-6, 6, 200)

cos = np.cos(x)
sin = np.sin(x)

plt.plot(x, cos, color='red', linewidth=2.5)
plt.plot(x, sin, color='green', linewidth=3.5)

#plt.xlim(x.min()+0.5, x.max()+0.5)
plt.xlim(x.min()-2, x.max()+2)
plt.ylim(sin.min()*1.3, sin.max()*1.3)
# Out:
# (-1.2997056838141292, 1.2997056838141292)

# %%
plt.figure(figsize=(10,5))

x = np.linspace(-6, 6, 200)

cos = np.cos(x)
sin = np.sin(x)

plt.plot(x, cos, color='red', linewidth=2.5)
plt.plot(x, sin, color='green', linewidth=3.5)

plt.xticks([-6,-3,0,1,3,6])
plt.yticks([-1,-.4,0,.5,.8,1])
# Out:
# ([<matplotlib.axis.YTick at 0x11cecb810>,
#   <matplotlib.axis.YTick at 0x11c88b350>,
#   <matplotlib.axis.YTick at 0x11c8b8150>,
#   <matplotlib.axis.YTick at 0x11be59d90>,
#   <matplotlib.axis.YTick at 0x11c6272d0>,
#   <matplotlib.axis.YTick at 0x11c627550>],
#  <a list of 6 Text yticklabel objects>)

# %% [markdown]
# # Subplots

# %%
# subplot = num of rows, num of col, fig num... eg subplot(211) subplot(2,1,1)

# %%
plt.figure(figsize=(10,5))
plt.subplot(211)

x = np.linspace(-10,10,150)
cos = np.cos(x)
sin = np.sin(x)

plt.plot(x, cos, color='red', linewidth=2.4)

plt.subplot(212)

plt.plot(x, sin, color='green', linewidth=3.4)

# %%
 plt.subplot(121)

x = np.linspace(-10,10,150)
cos = np.cos(x)
sin = np.sin(x)

plt.plot(x, cos, color='red', linewidth=2.4)

plt.subplot(122)

plt.plot(x, sin, color='green', linewidth=3.4)

# %%
plt.axes([-0.4,1,1,1]) # left, bottom, width, height

x = np.linspace(-10,10,150)
cos = np.cos(x)
sin = np.sin(x)

plt.plot(x, cos, color='red', linewidth=2.4)

plt.axes([1,1,1,1])

plt.plot(x, sin, color='green', linewidth=3.4)

# %%
plt.axes([-0.4,1,1,1.2]) # left, bottom, width, height

x = np.linspace(-10,10,150)
cos = np.cos(x)
sin = np.sin(x)

plt.plot(x, cos, color='red', linewidth=2.4)

plt.axes([1,1,1.2,1])

plt.plot(x, sin, color='green', linewidth=3.4)

# %% [markdown]
# # Adding Text

# %%
# labels, title, text and annot

# %%
x = np.linspace(-10,10,150)
cos = np.cos(x)
sin = np.sin(x)

plt.plot(x, cos, color='red', linewidth=3.0)

# %%
plt.plot(x, cos, color='red', linewidth=3.0)

plt.xlabel('X-axis')
plt.ylabel('cosx')
plt.title("Graph of x vs cosx")

# %%
plt.plot(x, cos, color='red', linewidth=3.0)

plt.xlabel('X-axis', fontsize=15, color='green')
plt.ylabel('cosx', fontsize=15, color='blue')
plt.title("Graph of x vs cosx")
plt.grid(True)

# %%
plt.plot(x, cos, color='red', linewidth=3.0)

plt.xlabel('X-axis', fontsize=15, color='green')
plt.ylabel('cosx', fontsize=15, color='blue')
plt.title("Graph of x vs cosx")
plt.grid(True)

plt.annotate('this is one max value', xy=(0,1), xytext=(5, 0.5),\
             arrowprops=dict(facecolor='black', shrink=0.09))

# %%
plt.plot(x, cos, color='red', linewidth=3.0)

plt.xlabel('X-axis', fontsize=15, color='green')
plt.ylabel('cosx', fontsize=15, color='blue')
plt.title("Graph of x vs cosx")
plt.grid(True)

plt.annotate('this is one max value', xy=(0,1), xytext=(7, 0.3),\
             arrowprops=dict(facecolor='black', shrink=0.14))

# %%
plt.plot(x, cos, color='red', linewidth=3.0)

plt.xlabel('X-axis', fontsize=15, color='green')
plt.ylabel('cosx', fontsize=15, color='blue')
plt.title("Graph of x vs cosx")
plt.grid(True)

plt.annotate('this is one max value', xy=(0,1), xytext=(2.5, 1.5),\
             arrowprops=dict(facecolor='black', shrink=0.09))

# %% [markdown]
# # Line styles and adding text labels

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

# %matplotlib inline

# %%
x = np.linspace(-10,10,150)
cos = np.cos(x)
sin = np.sin(x)

# %%
# :, -., --, -

# %%
plt.plot(x, cos, color='red', linewidth=3.8, linestyle=':')

# %%
plt.plot(x, sin, linewidth=3.5, linestyle='-.')

# %%
plt.plot(x, sin, linewidth=3.5,color='green', linestyle='--')
plt.plot(x, cos, linewidth=3.0,color='red', linestyle='-')

# %%
plt.plot(x, cos, color='green', linewidth=3.2)

plt.text(-4, -0.3, 'This text will be displayed across our plot', rotation=20, fontsize=14)

# %%
plt.plot(x, cos, color='green', linewidth=3.2)

plt.text(-7, 0, 'This text will be displayed across our plot', rotation=35, fontsize=14)

# %%
plt.plot(x, cos, color='green', linewidth=3.2)

plt.text(-8, 0, 'This text will be displayed across our plot', fontsize=14)

# %%
plt.plot(x, cos, color='green', linewidth=3.2)

plt.text(-4, -0.3, 'This text will be displayed across our plot', rotation=-20, fontsize=14)

# %%
plt.subplot(211)
plt.plot(x, cos, color='red', linewidth=2.8)
plt.text(-5,-0.5, 'this will run across our subplot', rotation=11, fontsize=14)

plt.subplot(212)
plt.plot(x, sin, color='green', linewidth=3.8)
plt.text(-5,-0.5, 'this will run across our subplot', rotation=-11, fontsize=14)

# %%
plt.figure(figsize=(10,6))

plt.subplot(121)
plt.plot(x, cos, color='red', linewidth=2.8)
plt.text(-5,-0.5, 'this will run across our subplot', rotation=11, fontsize=14)

plt.subplot(122)
plt.plot(x, sin, color='green', linewidth=3.8)
plt.text(-5,-0.5, 'this will run across our subplot', rotation=-11, fontsize=14)

# %% [markdown]
# # Exercise - putting it all together

# %%
# draw four subplots for sinx, cosx, -sinx, -cosx
# add titles to each of the subplots, use different linestyles for each subplot
# add text labels to one or more of the subplots

# %%
x = np.linspace(-6,6,180)
cos = np.cos(x)
sin = np.sin(x)

# %%
plt.figure(figsize=(10,7))

plt.subplot(221)
plt.plot(x, cos, color='red', linewidth=2.6, linestyle=':')
plt.title('cosx')
plt.grid(True)
plt.text(-5,-0.3, 'this will run across the subplot', rotation=10, fontsize=15)

plt.subplot(222)
plt.plot(x, sin, color='green', linewidth=3.0, linestyle='-.')
plt.title('sinx')
plt.grid(True)
plt.text(-5,-0.3, 'this will run across the subplot', rotation=-10, fontsize=15)

plt.subplot(223)
plt.plot(x, -cos, color='blue', linewidth=3.5, linestyle='--')
plt.title('-cosx')
plt.grid(True)

plt.subplot(224)
plt.plot(x, -sin, color='purple', linewidth=4.0, linestyle='-')
plt.title('-sinx')
plt.grid(True)
