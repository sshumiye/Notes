# %%
import pandas as pd
import numpy as np
from pandas import Series, DataFrame

# %%
# lxml, html5lib, beautifulsoup4

# %%
# conda install lxml
# conda install html5lib
# conda install beautifulsoup4

# %%
bank_url = 'https://www.fdic.gov/bank/individual/failed/banklist.html'

# %%
dframe = pd.read_html(bank_url)

# %%
#dframe

# %%
#dframe[0]

# %%
dframe[0][:10]
# Out:
#                        Bank Name             City  ST   CERT  \
# 0  Seaway Bank and Trust Company          Chicago  IL  19328
# 1         Harvest Community Bank       Pennsville  NJ  34951
# 2                    Allied Bank         Mulberry  AR     91
# 3   The Woodbury Banking Company         Woodbury  GA  11297
# 4         First CornerStone Bank  King of Prussia  PA  35312
# 5             Trust Company Bank          Memphis  TN   9956
# 6     North Milwaukee State Bank        Milwaukee  WI  20364
# 7         Hometown National Bank         Longview  WA  35156
# 8            The Bank of Georgia   Peachtree City  GA  35259
# 9                   Premier Bank           Denver  CO  34112
#
#                  Acquiring Institution        Closing Date       Updated Date
# 0                  State Bank of Texas    January 27, 2017   February 3, 2017
# 1  First-Citizens Bank & Trust Company    January 13, 2017   January 26, 2017
# ...

# %%
dframe[0][10:20]
# Out:
#                                  Bank Name         City  ST   CERT  \
# 10                          Edgebrook Bank      Chicago  IL  57772
# 11                  Doral Bank  En Espanol     San Juan  PR  32102
# 12       Capitol City Bank & Trust Company      Atlanta  GA  33938
# 13                 Highland Community Bank      Chicago  IL  20290
# 14        First National Bank of Crestview    Crestview  FL  17557
# 15                      Northern Star Bank      Mankato  MN  34983
# 16  Frontier Bank, FSB D/B/A El Paseo Bank  Palm Desert  CA  34738
# 17   The National Republic Bank of Chicago      Chicago  IL    916
# 18                          NBRS Financial   Rising Sun  MD   4862
# 19                   GreenChoice Bank, fsb      Chicago  IL  28462
#
#                   Acquiring Institution       Closing Date       Updated Date
# 10             Republic Bank of Chicago        May 8, 2015      July 12, 2016
# ...

# %%
# pd.io.html.read_html

# %%
bank_dframe = pd.io.html.read_html(bank_url)

# %%
#bank_dframe

# %%
bank_dframe[0][:5]
# Out:
#                        Bank Name             City  ST   CERT  \
# 0  Seaway Bank and Trust Company          Chicago  IL  19328
# 1         Harvest Community Bank       Pennsville  NJ  34951
# 2                    Allied Bank         Mulberry  AR     91
# 3   The Woodbury Banking Company         Woodbury  GA  11297
# 4         First CornerStone Bank  King of Prussia  PA  35312
#
#                  Acquiring Institution        Closing Date       Updated Date
# 0                  State Bank of Texas    January 27, 2017   February 3, 2017
# 1  First-Citizens Bank & Trust Company    January 13, 2017   January 26, 2017
# 2                         Today's Bank  September 23, 2016  November 17, 2016
# 3                          United Bank     August 19, 2016  November 17, 2016
# 4  First-Citizens Bank & Trust Company         May 6, 2016  September 6, 2016

# %%
state = 'https://simple.wikipedia.org/wiki/List_of_U.S._states'

# %%
x = pd.read_html(state)

# %%
x[0]
# Out:
#                0               1               2                  3
# 0   Abbreviation      State Name         Capital     Became a State
# 1             AL         Alabama      Montgomery  December 14, 1819
# 2             AK          Alaska          Juneau    January 3, 1960
# 3             AZ         Arizona         Phoenix  February 14, 1912
# 4             AR        Arkansas     Little Rock      June 15, 1836
# 5             CA      California      Sacramento  September 9, 1850
# 6             CO        Colorado          Denver     August 1, 1876
# 7             CT     Connecticut        Hartford    January 9, 1788
# 8             DE        Delaware           Dover   December 7, 1787
# 9             FL         Florida     Tallahassee      March 3, 1845
# 10            GA         Georgia         Atlanta    January 2, 1788
# 11            HI          Hawaii        Honolulu    August 21, 1959
# 12            ID           Idaho           Boise       July 3, 1890
# ...

# %%
x[0][:4]
# Out:
#               0           1           2                  3
# 0  Abbreviation  State Name     Capital     Became a State
# 1            AL     Alabama  Montgomery  December 14, 1819
# 2            AK      Alaska      Juneau    January 3, 1960
# 3            AZ     Arizona     Phoenix  February 14, 1912
