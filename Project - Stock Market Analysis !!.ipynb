# %% [markdown]
# We will analyse various stocks and answer questions related to stocks like the following
#
#  - What is the trend of price of the stocks over time?
#  - What does the average return of stocks look like?
#  - What does the daily stock return look like?
#  - Plot the moving averages for 20,50,100 and 200 days
#  - Do the stocks have any correlation? (Hint: draw some pairgrid, jointplots, pairplot...)
#
#  Google, apple, walmart, xom, sbux

# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame

import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

import datetime

import pandas.io.data as web

# %%
(start, end)

# %%
start = datetime.datetime(2015,10,10)
end = datetime.date.today()

# %%
google = web.DataReader('GOOG', 'yahoo', start, end)

# %%
google.head()
# Out:
#                   Open        High         Low       Close   Volume  \
# Date
# 2015-10-12  642.090027  648.500000  639.010010  646.669983  1275200
# 2015-10-13  643.150024  657.812012  643.150024  652.299988  1807700
# 2015-10-14  653.210022  659.390015  648.849976  651.159973  1415500
# 2015-10-15  654.659973  663.130005  654.460022  661.739990  1885700
# 2015-10-16  664.109985  664.969971  657.200012  662.200012  1611100
#
#              Adj Close
# Date
# 2015-10-12  646.669983
# 2015-10-13  652.299988
# 2015-10-14  651.159973
# 2015-10-15  661.739990
# 2015-10-16  662.200012

# %%
google.tail()
# Out:
#                   Open        High         Low       Close   Volume  \
# Date
# 2017-01-30  814.659973  815.840027  799.799988  802.320007  3228900
# 2017-01-31  796.859985  801.250000  790.520020  796.789978  2143500
# 2017-02-01  799.679993  801.190002  791.190002  795.695007  2023300
# 2017-02-02  793.799988  802.700012  792.000000  798.530029  1525800
# 2017-02-03  802.989990  806.000000  800.369995  801.489990  1460400
#
#              Adj Close
# Date
# 2017-01-30  802.320007
# 2017-01-31  796.789978
# 2017-02-01  795.695007
# 2017-02-02  798.530029
# 2017-02-03  801.489990

# %%
type(google)
# Out:
# pandas.core.frame.DataFrame

# %%
google.describe()
# Out:
#              Open        High         Low       Close        Volume  \
# count  332.000000  332.000000  332.000000  332.000000  3.320000e+02
# mean   745.264336  750.995752  739.089368  745.141054  1.839901e+06
# std     38.448112   37.495583   38.852241   38.123277  9.057379e+05
# min    642.090027  648.500000  639.010010  642.609985  5.272000e+05
# 25%    716.714996  722.152511  710.007507  716.375000  1.293300e+06
# 50%    747.004975  752.399994  738.395019  745.799988  1.609550e+06
# 75%    775.484985  780.369980  770.494980  775.027512  2.092225e+06
# max    837.809998  841.950012  827.010010  835.669983  6.653900e+06
#
#         Adj Close
# count  332.000000
# mean   745.141054
# std     38.123277
# min    642.609985
# 25%    716.375000
# 50%    745.799988
# 75%    775.027512
# max    835.669983

# %%
google.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 332 entries, 2015-10-12 to 2017-02-03
# Data columns (total 6 columns):
# Open         332 non-null float64
# High         332 non-null float64
# Low          332 non-null float64
# Close        332 non-null float64
# Volume       332 non-null int64
# Adj Close    332 non-null float64
# dtypes: float64(5), int64(1)
# memory usage: 18.2 KB

# %%
sbux = web.DataReader('SBUX', 'yahoo', start, end)

# %%
sbux.head()
# Out:
#                  Open       High        Low      Close    Volume  Adj Close
# Date
# 2015-10-12  60.349998  60.889999  60.040001  60.540001   6430300  59.454914
# 2015-10-13  60.340000  60.750000  60.020000  60.160000   6262800  59.081724
# 2015-10-14  60.000000  60.169998  58.430000  58.820000   8365600  57.765741
# 2015-10-15  58.950001  59.830002  58.080002  59.689999   9745900  58.620146
# 2015-10-16  59.959999  60.290001  59.459999  59.930000  12860800  58.855846

# %%
xom = web.DataReader('XOM', 'yahoo', start, end)

# %%
apple = web.DataReader('AAPL', 'yahoo', start, end)

# %%
wmt = web.DataReader('WMT', 'yahoo', start, end)

# %%
xom['Adj Close'].plot(legend=True, figsize=(10,6))

# %%
google['Adj Close'].plot(legend=True, color='blue', figsize=(10,6))

# %%
google['Adj Close'].plot(legend=True, color='blue', figsize=(10,6))
xom['Adj Close'].plot(legend=True, color='green', figsize=(10,6))
sbux['Adj Close'].plot(legend=True, color='red', figsize=(10,6))
wmt['Adj Close'].plot(legend=True, color='purple', figsize=(10,6))
apple['Adj Close'].plot(legend=True, color='orange', figsize=(10,6))

# %%
xom['Adj Close'].plot(legend=True, color='green', figsize=(10,6))
sbux['Adj Close'].plot(legend=True, color='red', figsize=(10,6))
wmt['Adj Close'].plot(legend=True, color='purple', figsize=(10,6))
apple['Adj Close'].plot(legend=True, color='orange', figsize=(10,6))

# %%
# let's visualize the daily return for the stocks

# %%
wmt['daily_return'] = wmt['Adj Close'].pct_change()

# %%
wmt.head()
# Out:
#                  Open       High        Low      Close    Volume  Adj Close  \
# Date
# 2015-10-12  66.669998  67.000000  66.580002  66.930000   5643900  64.501043
# 2015-10-13  66.620003  66.940002  66.260002  66.730003   8858400  64.308305
# 2015-10-14  66.610001  67.949997  60.020000  60.029999  80898100  57.851450
# 2015-10-15  59.700001  60.470001  58.610001  59.330002  46253500  57.176857
# 2015-10-16  59.470001  59.490002  58.369999  58.889999  26195100  56.752822
#
#             daily_return
# Date
# 2015-10-12           NaN
# 2015-10-13     -0.002988
# 2015-10-14     -0.100405
# 2015-10-15     -0.011661
# 2015-10-16     -0.007416

# %%
wmt['daily_return'].plot(figsize=(13,8), linestyle=':', marker='o', color='blue', legend=True)

# %%
google['daily_return'] = google['Adj Close'].pct_change()

# %%
google.head()
# Out:
#                   Open        High         Low       Close   Volume  \
# Date
# 2015-10-12  642.090027  648.500000  639.010010  646.669983  1275200
# 2015-10-13  643.150024  657.812012  643.150024  652.299988  1807700
# 2015-10-14  653.210022  659.390015  648.849976  651.159973  1415500
# 2015-10-15  654.659973  663.130005  654.460022  661.739990  1885700
# 2015-10-16  664.109985  664.969971  657.200012  662.200012  1611100
#
#              Adj Close  daily_return
# Date
# 2015-10-12  646.669983           NaN
# 2015-10-13  652.299988      0.008706
# 2015-10-14  651.159973     -0.001748
# 2015-10-15  661.739990      0.016248
# 2015-10-16  662.200012      0.000695

# %%
google['daily_return'].plot(figsize=(13,8), linestyle=':', marker='o', color='green', legend=True)

# %%
sbux['daily_return'] = sbux['Adj Close'].pct_change()

# %%
sbux.head(10)
# Out:
#                  Open       High        Low      Close    Volume  Adj Close  \
# Date
# 2015-10-12  60.349998  60.889999  60.040001  60.540001   6430300  59.454914
# 2015-10-13  60.340000  60.750000  60.020000  60.160000   6262800  59.081724
# 2015-10-14  60.000000  60.169998  58.430000  58.820000   8365600  57.765741
# 2015-10-15  58.950001  59.830002  58.080002  59.689999   9745900  58.620146
# 2015-10-16  59.959999  60.290001  59.459999  59.930000  12860800  58.855846
# 2015-10-19  60.130001  61.290001  59.869999  60.970001   8117200  59.877207
# 2015-10-20  61.220001  61.360001  60.560001  60.880001   6061000  59.788820
# 2015-10-21  61.070000  61.119999  60.160000  60.529999   6055300  59.445091
# 2015-10-22  60.959999  61.709999  60.169998  61.490002   9182000  60.387887
# 2015-10-23  62.110001  62.799999  61.619999  62.610001   8206000  61.487812
#
#             daily_return
# Date
# 2015-10-12           NaN
# 2015-10-13     -0.006277
# 2015-10-14     -0.022274
# 2015-10-15      0.014791
# 2015-10-16      0.004021
# 2015-10-19      0.017354
# 2015-10-20     -0.001476
# 2015-10-21     -0.005749
# 2015-10-22      0.015860
# 2015-10-23      0.018214

# %%
sbux['daily_return'].plot(figsize=(13,8), linestyle=':', marker='o', color='red', legend=True)

# %%
stocks = pd.DataFrame({'AAPL': apple['Adj Close'],\
                      'SBUX': sbux['Adj Close'],\
                      'WMT': wmt['Adj Close'],\
                      'GOOG': google['Adj Close'],\
                      'XOM': xom['Adj Close']})

# %%
stocks.head()
# Out:
#                   AAPL        GOOG       SBUX        WMT        XOM
# Date
# 2015-10-12  108.705713  646.669983  59.454914  64.501043  75.932654
# 2015-10-13  108.890788  652.299988  59.081724  64.308305  75.798599
# 2015-10-14  107.351763  651.159973  57.765741  57.851450  76.756136
# 2015-10-15  108.958972  661.739990  58.620146  57.176857  78.020084
# 2015-10-16  108.160239  662.200012  58.855846  56.752822  78.977620

# %%
stocks.tail()
# Out:
#                   AAPL        GOOG       SBUX        WMT        XOM
# Date
# 2017-01-30  121.629997  802.320007  55.900002  66.419998  84.860001
# 2017-01-31  121.349998  796.789978  55.220001  66.739998  83.889999
# 2017-02-01  128.750000  795.695007  53.900002  66.230003  82.940002
# 2017-02-02  128.529999  798.530029  53.869999  66.699997  83.449997
# 2017-02-03  129.080002  801.489990  55.060001  66.500000  83.540001

# %%
stocks.plot(figsize=(10,6))

# %%
stock_return = stocks.apply(lambda a: a/a[0])

# %%
stock_return.head()
# Out:
#                 AAPL      GOOG      SBUX       WMT       XOM
# Date
# 2015-10-12  1.000000  1.000000  1.000000  1.000000  1.000000
# 2015-10-13  1.001703  1.008706  0.993723  0.997012  0.998235
# 2015-10-14  0.987545  1.006943  0.971589  0.896907  1.010845
# 2015-10-15  1.002330  1.023304  0.985960  0.886449  1.027491
# 2015-10-16  0.994982  1.024015  0.989924  0.879874  1.040101

# %%
stock_return.tail()
# Out:
#                 AAPL      GOOG      SBUX       WMT       XOM
# Date
# 2017-01-30  1.118892  1.240695  0.940208  1.029751  1.117569
# 2017-01-31  1.116317  1.232143  0.928771  1.034712  1.104795
# 2017-02-01  1.184390  1.230450  0.906569  1.026805  1.092284
# 2017-02-02  1.182367  1.234834  0.906065  1.034092  1.099000
# 2017-02-03  1.187426  1.239411  0.926080  1.030991  1.100185

# %%
stock_return.plot(figsize=(10,8))

# %%
stock_return.head()
# Out:
#                 AAPL      GOOG      SBUX       WMT       XOM
# Date
# 2015-10-12  1.000000  1.000000  1.000000  1.000000  1.000000
# 2015-10-13  1.001703  1.008706  0.993723  0.997012  0.998235
# 2015-10-14  0.987545  1.006943  0.971589  0.896907  1.010845
# 2015-10-15  1.002330  1.023304  0.985960  0.886449  1.027491
# 2015-10-16  0.994982  1.024015  0.989924  0.879874  1.040101

# %%
# sns joinplot

# %%
sns.jointplot('GOOG', 'GOOG', stock_return, kind='scatter', color='red')

# %%
sns.jointplot('SBUX', 'SBUX', stock_return, kind='scatter', color='green')

# %%
sns.jointplot('GOOG', 'SBUX', stock_return, kind='scatter', color='red')

# %%
sns.jointplot('GOOG', 'AAPL', stock_return, kind='scatter', color='blue')

# %%
sns.jointplot('XOM', 'SBUX', stock_return, kind='scatter', color='red')

# %%
sns.jointplot('SBUX', 'WMT', stock_return, kind='scatter', color='green')

# %%
# pairplots

# %%
sns.pairplot(stock_return.dropna())

# %%
# how about parigrid?

# %%
stock_return_fig = sns.PairGrid(stock_return.dropna())
stock_return_fig.map_upper(plt.scatter, color='blue')
stock_return_fig.map_lower(sns.kdeplot, cmap='RdBu')
stock_return_fig.map_diag(plt.hist, bins=23)

# %%
stocks.head()
# Out:
#                   AAPL        GOOG       SBUX        WMT        XOM
# Date
# 2015-10-12  108.705713  646.669983  59.454914  64.501043  75.932654
# 2015-10-13  108.890788  652.299988  59.081724  64.308305  75.798599
# 2015-10-14  107.351763  651.159973  57.765741  57.851450  76.756136
# 2015-10-15  108.958972  661.739990  58.620146  57.176857  78.020084
# 2015-10-16  108.160239  662.200012  58.855846  56.752822  78.977620

# %%
return_pct = stocks.pct_change()

# %%
return_pct.head()
# Out:
#                 AAPL      GOOG      SBUX       WMT       XOM
# Date
# 2015-10-12       NaN       NaN       NaN       NaN       NaN
# 2015-10-13  0.001703  0.008706 -0.006277 -0.002988 -0.001765
# 2015-10-14 -0.014134 -0.001748 -0.022274 -0.100405  0.012633
# 2015-10-15  0.014971  0.016248  0.014791 -0.011661  0.016467
# 2015-10-16 -0.007331  0.000695  0.004021 -0.007416  0.012273

# %%
sns.pairplot(return_pct.dropna())

# %%
# moving averages ( rolling window = 20, 50, 100, 200)

# %%
stocks.head()
# Out:
#                   AAPL        GOOG       SBUX        WMT        XOM
# Date
# 2015-10-12  108.705713  646.669983  59.454914  64.501043  75.932654
# 2015-10-13  108.890788  652.299988  59.081724  64.308305  75.798599
# 2015-10-14  107.351763  651.159973  57.765741  57.851450  76.756136
# 2015-10-15  108.958972  661.739990  58.620146  57.176857  78.020084
# 2015-10-16  108.160239  662.200012  58.855846  56.752822  78.977620

# %%
google.head()
# Out:
#                   Open        High         Low       Close   Volume  \
# Date
# 2015-10-12  642.090027  648.500000  639.010010  646.669983  1275200
# 2015-10-13  643.150024  657.812012  643.150024  652.299988  1807700
# 2015-10-14  653.210022  659.390015  648.849976  651.159973  1415500
# 2015-10-15  654.659973  663.130005  654.460022  661.739990  1885700
# 2015-10-16  664.109985  664.969971  657.200012  662.200012  1611100
#
#              Adj Close  daily_return
# Date
# 2015-10-12  646.669983           NaN
# 2015-10-13  652.299988      0.008706
# 2015-10-14  651.159973     -0.001748
# 2015-10-15  661.739990      0.016248
# 2015-10-16  662.200012      0.000695

# %%
google['20d'] = google['Close'].rolling(window=20, center=False).mean()

# %%
google['20d'].plot(figsize=(10,6))

# %%
google['20d'].plot(figsize=(10,6))
google['Close'].plot(figsize=(10,6), color='red')

# %%
apple['20d'] = apple['Close'].rolling(window=20, center=False).mean()

# %%
apple['20d'].plot(figsize=(10,6), color='blue')

# %%
apple['20d'].plot(figsize=(10,6), color='red')
apple['Close'].plot(figsize=(10,6), color='blue')

# %%
# 50 days mov av

# %%
apple['50d'] = apple['Close'].rolling(window=50, center=False).mean()

# %%
apple['50d'].plot(figsize=(10,6), color='red')
apple['Close'].plot(figsize=(10,6), color='blue')

# %%
# 20, 50, 100, 200

# %%
google['50d'] = google['Close'].rolling(window=50, center=False).mean()

# %%
google['100d'] = google['Close'].rolling(window=100, center=False).mean()

# %%
google['200d'] = google['Close'].rolling(window=200, center=False).mean()

# %%
google['Close'].plot(figsize=(10,6), color='blue',legend=True)
google['20d'].plot(figsize=(10,6), color='red', legend=True)
google['50d'].plot(figsize=(10,6), color='green', legend=True)
google['100d'].plot(figsize=(10,6), color='orange', legend=True)
google['200d'].plot(figsize=(10,6), color='purple', legend=True)

# %%
google['Close'].plot(figsize=(10,6), color='blue',legend=True)

google['200d'].plot(figsize=(10,6), color='purple', legend=True)

# %%
xom['20d'] = xom['Close'].rolling(window=20, center=False).mean()

# %%
xom['Close'].plot(figsize=(10,6),color='red',legend=True)
xom['20d'].plot(figsize=(10,6), color='blue', legend=True)
