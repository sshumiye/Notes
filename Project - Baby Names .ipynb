# %%
import pandas as pd
import numpy as np
from pandas import Series, DataFrame

# %%
baby = pd.read_csv('baby_names.csv')

# %%
baby.head()
# Out:
#    year     name      prop  sex soundex
# 0  1880     John  0.081541  boy    J500
# 1  1880  William  0.080511  boy    W450
# 2  1880    James  0.050057  boy    J520
# 3  1880  Charles  0.045167  boy    C642
# 4  1880   George  0.043292  boy    G620

# %%
baby[baby.year == 1880].head(10)
# Out:
#    year     name      prop  sex soundex
# 0  1880     John  0.081541  boy    J500
# 1  1880  William  0.080511  boy    W450
# 2  1880    James  0.050057  boy    J520
# 3  1880  Charles  0.045167  boy    C642
# 4  1880   George  0.043292  boy    G620
# 5  1880    Frank  0.027380  boy    F652
# 6  1880   Joseph  0.022229  boy    J210
# 7  1880   Thomas  0.021401  boy    T520
# 8  1880    Henry  0.020641  boy    H560
# 9  1880   Robert  0.020404  boy    R163

# %%
# Divide the data into boy names and girl names

# %%
boy_names = baby[baby.sex == 'boy']

# %%
girl_names = baby[baby.sex == 'girl']

# %%
# How many names are there in each of the given years? (hint: groupby year...)

# %%
baby.groupby('year').size()
# Out:
# year
# 1880    2000
# 1881    2000
# 1882    2000
# 1883    2000
# 1884    2000
# 1885    2000
# 1886    2000
# 1887    2000
# 1888    2000
# 1889    2000
# 1890    2000
# 1891    2000
# 1892    2000
# 1893    2000
# 1894    2000
# 1895    2000
# 1896    2000
# 1897    2000
# 1898    2000
# 1899    2000
# 1900    2000
# 1901    2000
# 1902    2000
# 1903    2000
# 1904    2000
# 1905    2000
# 1906    2000
# 1907    2000
# 1908    2000
# 1909    2000
#         ...
# 1979    2000
# 1980    2000
# 1981    2000
# 1982    2000
# 1983    2000
# 1984    2000
# 1985    2000
# 1986    2000
# 1987    2000
# 1988    2000
# 1989    2000
# 1990    2000
# 1991    2000
# 1992    2000
# 1993    2000
# 1994    2000
# 1995    2000
# 1996    2000
# 1997    2000
# 1998    2000
# 1999    2000
# 2000    2000
# 2001    2000
# 2002    2000
# 2003    2000
# 2004    2000
# 2005    2000
# 2006    2000
# 2007    2000
# 2008    2000
# dtype: int64

# %%
# How many boy names and girl names are there in each of the given years? (hint: groupby year...)

# %%
boy_names.groupby('year').size()
girl_names.groupby('year').size()
# Out:
# year
# 1880    1000
# 1881    1000
# 1882    1000
# 1883    1000
# 1884    1000
# 1885    1000
# 1886    1000
# 1887    1000
# 1888    1000
# 1889    1000
# 1890    1000
# 1891    1000
# 1892    1000
# 1893    1000
# 1894    1000
# 1895    1000
# 1896    1000
# 1897    1000
# 1898    1000
# 1899    1000
# 1900    1000
# 1901    1000
# 1902    1000
# 1903    1000
# 1904    1000
# 1905    1000
# 1906    1000
# 1907    1000
# 1908    1000
# 1909    1000
#         ...
# 1979    1000
# 1980    1000
# 1981    1000
# 1982    1000
# 1983    1000
# 1984    1000
# 1985    1000
# 1986    1000
# 1987    1000
# 1988    1000
# 1989    1000
# 1990    1000
# 1991    1000
# 1992    1000
# 1993    1000
# 1994    1000
# 1995    1000
# 1996    1000
# 1997    1000
# 1998    1000
# 1999    1000
# 2000    1000
# 2001    1000
# 2002    1000
# 2003    1000
# 2004    1000
# 2005    1000
# 2006    1000
# 2007    1000
# 2008    1000
# dtype: int64

# %%
# group by

# %%
type(boy_names.groupby('year').size())
# Out:
# pandas.core.series.Series

# %%
# group babynames by both year and sex and compare it to your result above

# %%
baby.groupby(['year','sex']).size()
# Out:
# year  sex
# 1880  boy     1000
#       girl    1000
# 1881  boy     1000
#       girl    1000
# 1882  boy     1000
#       girl    1000
# 1883  boy     1000
#       girl    1000
# 1884  boy     1000
#       girl    1000
# 1885  boy     1000
#       girl    1000
# 1886  boy     1000
#       girl    1000
# 1887  boy     1000
#       girl    1000
# 1888  boy     1000
#       girl    1000
# 1889  boy     1000
#       girl    1000
# 1890  boy     1000
#       girl    1000
# 1891  boy     1000
#       girl    1000
# 1892  boy     1000
#       girl    1000
# 1893  boy     1000
#       girl    1000
# 1894  boy     1000
#       girl    1000
#               ...
# 1994  boy     1000
#       girl    1000
# 1995  boy     1000
#       girl    1000
# 1996  boy     1000
#       girl    1000
# 1997  boy     1000
#       girl    1000
# 1998  boy     1000
#       girl    1000
# 1999  boy     1000
#       girl    1000
# 2000  boy     1000
#       girl    1000
# 2001  boy     1000
#       girl    1000
# ...

# %%
# group baby names by year and sex and find out how many boys' and girls' names are there 
# for years 1980,1990 and 2000?

# %%
names_1980 = baby.groupby(['year','sex']).size()
names_1980.ix[1980]
# Out:
# sex
# boy     1000
# girl    1000
# dtype: int64

# %%
names_1990 = baby.groupby(['year','sex']).size()
names_1980.ix[1990]
# Out:
# sex
# boy     1000
# girl    1000
# dtype: int64

# %%
# Find the most popular baby names for the years 1980, 1990 and 2000. How about girl names?

# %%
boy_names[boy_names.year == 1990]
# Out:
#         year         name      prop  sex soundex
# 110000  1990      Michael  0.030358  boy    M240
# 110001  1990  Christopher  0.024387  boy    C623
# 110002  1990      Matthew  0.020832  boy    M300
# 110003  1990       Joshua  0.020095  boy    J200
# 110004  1990       Daniel  0.015717  boy    D540
# 110005  1990        David  0.015684  boy    D130
# 110006  1990       Andrew  0.015644  boy    A536
# 110007  1990        James  0.015042  boy    J520
# 110008  1990       Justin  0.014248  boy    J235
# 110009  1990       Joseph  0.014001  boy    J210
# 110010  1990         Ryan  0.013598  boy    R500
# 110011  1990         John  0.013518  boy    J500
# 110012  1990       Robert  0.013421  boy    R163
# 110013  1990     Nicholas  0.012980  boy    N242
# 110014  1990      Anthony  0.011662  boy    A535
# 110015  1990      William  0.011569  boy    W450
# 110016  1990     Jonathan  0.011190  boy    J535
# 110017  1990         Kyle  0.010557  boy    K400
# ...

# %%
type(boy_names[boy_names.year == 1990])
# Out:
# pandas.core.frame.DataFrame

# %%
boy_names[boy_names.year == 1990].prop
# Out:
# 110000    0.030358
# 110001    0.024387
# 110002    0.020832
# 110003    0.020095
# 110004    0.015717
# 110005    0.015684
# 110006    0.015644
# 110007    0.015042
# 110008    0.014248
# 110009    0.014001
# 110010    0.013598
# 110011    0.013518
# 110012    0.013421
# 110013    0.012980
# 110014    0.011662
# 110015    0.011569
# 110016    0.011190
# 110017    0.010557
# 110018    0.010305
# 110019    0.010228
# 110020    0.009596
# 110021    0.009500
# 110022    0.009486
# 110023    0.009028
# 110024    0.008723
# 110025    0.008470
# 110026    0.007870
# 110027    0.007528
# 110028    0.007500
# 110029    0.007298
#             ...
# 110970    0.000054
# 110971    0.000054
# 110972    0.000054
# 110973    0.000054
# 110974    0.000054
# 110975    0.000054
# 110976    0.000054
# 110977    0.000054
# 110978    0.000053
# 110979    0.000053
# 110980    0.000053
# 110981    0.000053
# 110982    0.000053
# 110983    0.000053
# 110984    0.000053
# 110985    0.000053
# ...

# %%
boy_prop = boy_names[boy_names.year == 1990].prop

# %%
boy_prop.idxmax()
# Out:
# 110000

# %%
prop_max = boy_prop.idxmax()

# %%
boy_names.ix[prop_max]
# Out:
# year           1990
# name        Michael
# prop       0.030358
# sex             boy
# soundex        M240
# Name: 110000, dtype: object

# %%
# Use the set_index method to index boy names by name and year

# %%
indexed = boy_names.set_index(['name', 'year'])

# %%
indexed[:10]
indexed[-10:]
# Out:
#                    prop  sex soundex
# name     year
# Baron    2008  0.000090  boy    B650
# Carlo    2008  0.000090  boy    C640
# Carsen   2008  0.000090  boy    C625
# Fletcher 2008  0.000090  boy    F432
# Izayah   2008  0.000090  boy    I200
# Kolten   2008  0.000090  boy    K435
# Damari   2008  0.000089  boy    D560
# Hugh     2008  0.000089  boy    H200
# Jensen   2008  0.000089  boy    J525
# Yurem    2008  0.000089  boy    Y650

# %%
# Take the name Matthew and apply the indexed method above on the name "Matthew",
# then analyze the prop for each year and plot it

# %%
boy_names[boy_names.name == 'Matthew']
# Out:
#         year     name      prop  sex soundex
# 116     1880  Matthew  0.000954  boy    M300
# 1156    1881  Matthew  0.000739  boy    M300
# 2126    1882  Matthew  0.000893  boy    M300
# 3151    1883  Matthew  0.000765  boy    M300
# 4123    1884  Matthew  0.000953  boy    M300
# 5123    1885  Matthew  0.000957  boy    M300
# 6123    1886  Matthew  0.000941  boy    M300
# 7122    1887  Matthew  0.000988  boy    M300
# 8135    1888  Matthew  0.000885  boy    M300
# 9117    1889  Matthew  0.000991  boy    M300
# 10164   1890  Matthew  0.000718  boy    M300
# 11122   1891  Matthew  0.001034  boy    M300
# 12127   1892  Matthew  0.001004  boy    M300
# 13137   1893  Matthew  0.000892  boy    M300
# 14131   1894  Matthew  0.000993  boy    M300
# 15138   1895  Matthew  0.000884  boy    M300
# 16135   1896  Matthew  0.000953  boy    M300
# 17155   1897  Matthew  0.000820  boy    M300
# 18134   1898  Matthew  0.001007  boy    M300
# 19150   1899  Matthew  0.000877  boy    M300
# ...

# %%
indexed.ix['Matthew']
# Out:
#           prop  sex soundex
# year
# 1880  0.000954  boy    M300
# 1881  0.000739  boy    M300
# 1882  0.000893  boy    M300
# 1883  0.000765  boy    M300
# 1884  0.000953  boy    M300
# 1885  0.000957  boy    M300
# 1886  0.000941  boy    M300
# 1887  0.000988  boy    M300
# 1888  0.000885  boy    M300
# 1889  0.000991  boy    M300
# 1890  0.000718  boy    M300
# 1891  0.001034  boy    M300
# 1892  0.001004  boy    M300
# 1893  0.000892  boy    M300
# 1894  0.000993  boy    M300
# 1895  0.000884  boy    M300
# 1896  0.000953  boy    M300
# 1897  0.000820  boy    M300
# 1898  0.001007  boy    M300
# 1899  0.000877  boy    M300
# 1900  0.000801  boy    M300
# 1901  0.000779  boy    M300
# 1902  0.000783  boy    M300
# 1903  0.000789  boy    M300
# 1904  0.000700  boy    M300
# 1905  0.000747  boy    M300
# 1906  0.000951  boy    M300
# 1907  0.000782  boy    M300
# 1908  0.000920  boy    M300
# 1909  0.000837  boy    M300
# ...        ...  ...     ...
# 1979  0.019894  boy    M300
# ...

# %%
% matplotlib inline

# %%
indexed.ix['Matthew'].prop.plot()

# %%
# analyze the proportion of boy_names by using the describe() method

# %%
boy_names['prop'].describe()
# Out:
# count    129000.000000
# mean          0.000916
# std           0.003441
# min           0.000026
# 25%           0.000071
# 50%           0.000142
# 75%           0.000453
# max           0.081541
# Name: prop, dtype: float64

# %%
# calculate the mean of the proportion of each boy names

# %%
boy_names.groupby('name')['prop'].mean()
# Out:
# name
# Aaden        0.000442
# Aarav        0.000101
# Aaron        0.002266
# Ab           0.000044
# Abb          0.000046
# Abbie        0.000046
# Abbott       0.000044
# Abdiel       0.000092
# Abdul        0.000064
# Abdullah     0.000094
# Abe          0.000225
# Abel         0.000152
# Abelardo     0.000041
# Abie         0.000042
# Abner        0.000130
# Abraham      0.000494
# Abram        0.000105
# Ace          0.000080
# Acey         0.000042
# Acie         0.000062
# Acy          0.000046
# Ada          0.000057
# Adalberto    0.000051
# Adam         0.002242
# Adams        0.000053
# Adan         0.000131
# Add          0.000043
# Addie        0.000065
# Addison      0.000114
# Adelard      0.000065
#                ...
# Yoshio       0.000054
# Young        0.000080
# Yurem        0.000091
# Yusuf        0.000096
# Zachariah    0.000275
# Zachary      0.003748
# Zachery      0.000369
# Zack         0.000113
# Zackary      0.000373
# Zackery      0.000232
# ...

# %%
# Use the describe method to get statistics of the proportion of boy_names for each year

# %%
prop_stat = boy_names.groupby('year')['prop'].describe()

# %%
prop_stat[:20]
# Out:
# year
# 1880  count    1000.000000
#       mean        0.000931
#       std         0.004871
#       min         0.000042
#       25%         0.000059
#       50%         0.000118
#       75%         0.000372
#       max         0.081541
# 1881  count    1000.000000
#       mean        0.000930
#       std         0.004812
#       min         0.000037
#       25%         0.000065
#       50%         0.000120
#       75%         0.000369
#       max         0.080975
# 1882  count    1000.000000
#       mean        0.000928
#       std         0.004691
#       min         0.000041
# Name: prop, dtype: float64

# %%
# Use the sort_index (sort_values) method to sort boy names (by proportion) 
# for the years 1980 and 1990

# %%
boy_names[boy_names.year == 1980].sort_index(by='prop')
# Out:
# /anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:1: FutureWarning: by argument to sort_index is deprecated, pls use .sort_values(by=...)
#   if __name__ == '__main__':
#         year         name      prop  sex soundex
# 100999  1980       Nathen  0.000044  boy    N350
# 100993  1980      Cordell  0.000044  boy    C634
# 100994  1980    Cristobal  0.000044  boy    C623
# 100998  1980     Muhammad  0.000044  boy    M530
# 100996  1980       Isaias  0.000044  boy    I220
# 100995  1980      Horacio  0.000044  boy    H620
# 100997  1980     Kimberly  0.000044  boy    K516
# 100992  1980          Kai  0.000045  boy    K000
# 100980  1980         Coby  0.000045  boy    C100
# 100981  1980  Constantine  0.000045  boy    C523
# 100982  1980      Estevan  0.000045  boy    E231
# 100984  1980      Lashawn  0.000045  boy    L250
# 100985  1980        Sarah  0.000045  boy    S600
# 100983  1980        Hiram  0.000045  boy    H650
# 100987  1980      Westley  0.000045  boy    W234
# ...

# %%
boy_names[boy_names.year == 1980].sort_values(by='prop')
# Out:
#         year         name      prop  sex soundex
# 100999  1980       Nathen  0.000044  boy    N350
# 100993  1980      Cordell  0.000044  boy    C634
# 100994  1980    Cristobal  0.000044  boy    C623
# 100998  1980     Muhammad  0.000044  boy    M530
# 100996  1980       Isaias  0.000044  boy    I220
# 100995  1980      Horacio  0.000044  boy    H620
# 100997  1980     Kimberly  0.000044  boy    K516
# 100992  1980          Kai  0.000045  boy    K000
# 100980  1980         Coby  0.000045  boy    C100
# 100981  1980  Constantine  0.000045  boy    C523
# 100982  1980      Estevan  0.000045  boy    E231
# 100984  1980      Lashawn  0.000045  boy    L250
# 100985  1980        Sarah  0.000045  boy    S600
# 100983  1980        Hiram  0.000045  boy    H650
# 100987  1980      Westley  0.000045  boy    W234
# 100988  1980      Antwain  0.000045  boy    A535
# 100989  1980       Dustan  0.000045  boy    D235
# 100990  1980       Gideon  0.000045  boy    G350
# ...

# %%
boy_names[boy_names.year == 1990].prop.rank()
# Out:
# 110000    1000.0
# 110001     999.0
# 110002     998.0
# 110003     997.0
# 110004     996.0
# 110005     995.0
# 110006     994.0
# 110007     993.0
# 110008     992.0
# 110009     991.0
# 110010     990.0
# 110011     989.0
# 110012     988.0
# 110013     987.0
# 110014     986.0
# 110015     985.0
# 110016     984.0
# 110017     983.0
# 110018     982.0
# 110019     981.0
# 110020     980.0
# 110021     979.0
# 110022     978.0
# 110023     977.0
# 110024     976.0
# 110025     975.0
# 110026     974.0
# 110027     973.0
# 110028     972.0
# 110029     971.0
#            ...
# 110970      31.0
# 110971      31.0
# 110972      31.0
# 110973      31.0
# 110974      31.0
# 110975      31.0
# 110976      31.0
# 110977      31.0
# 110978      14.0
# 110979      14.0
# 110980      14.0
# 110981      14.0
# 110982      14.0
# 110983      14.0
# 110984      14.0
# 110985      14.0
# 110986      14.0
# 110987      14.0
# 110988      14.0
# 110989      14.0
# 110990      14.0
# ...

# %%
# Take boys name and group it by year and index by proportion
# then transform your grouped object by rank

# %%
grouped_boys = boy_names.groupby('year')['prop']

# %%
grouped_boys # -- is a seriesgroup by object

# %%
grouped_boys.transform(Series.rank)
# Out:
# 0         1000.0
# 1          999.0
# 2          998.0
# 3          997.0
# 4          996.0
# 5          995.0
# 6          994.0
# 7          993.0
# 8          992.0
# 9          991.0
# 10         990.0
# 11         989.0
# 12         988.0
# 13         987.0
# 14         986.0
# 15         985.0
# 16         984.0
# 17         983.0
# 18         982.0
# 19         981.0
# 20         979.5
# 21         979.5
# 22         978.0
# 23         977.0
# 24         976.0
# 25         975.0
# 26         974.0
# 27         973.0
# 28         972.0
# 29         971.0
#            ...
# 128970      28.0
# 128971      28.0
# 128972      28.0
# 128973      28.0
# 128974      28.0
# 128975      28.0
# 128976      28.0
# 128977      20.5
# 128978      20.5
# 128979      20.5
# 128980      20.5
# 128981      20.5
# 128982      20.5
# 128983      16.0
# 128984      16.0
# 128985      16.0
# 128986      12.5
# 128987      12.5
# 128988      12.5
# 128989      12.5
# 128990       7.5
# ...
